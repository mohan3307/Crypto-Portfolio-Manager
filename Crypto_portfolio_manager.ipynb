# %% [markdown]
# <a href="https://colab.research.google.com/github/mohan3307/Crypto-Portfolio-Manager/blob/main/Crypto_portfolio_manager.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# basics

# %%
# Single line comment

'''
Multi
line
comment
'''

print("Cryto Portfolio Manager")
# Out:
# Cryto Portfolio Manager

# %% [markdown]
# variables and datatypes

# %%
a = 10
b = 2.6
c = "string"
d = True
e = None
f = [1, 2, 3, 4, 5]
g = (1, 2, 3, 4, 5)
h = {"name": "John", "age": 30, "city": "New York"}
i = {1, 2, 3, 4, 5}
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
print(type(g))
print(type(h))
print(type(i))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'NoneType'>
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>
# <class 'set'>
